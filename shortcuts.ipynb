// %% [markdown]
// M -> Markdown\
// Y -> Code\
// C -> Copy cell\
// X -> Cut cell\
// V -> Paste cell\
// Shift + V -> Paste cell above\
// A -> Create cell above\
// B -> Create cell bellow\
// D -> Delete cell\
// Z -> Undo delete cell\
// Shift + Enter -> Execute cell and go to next\
// Ctrl + Enter -> Execute cell\
// L -> Show line numeration
